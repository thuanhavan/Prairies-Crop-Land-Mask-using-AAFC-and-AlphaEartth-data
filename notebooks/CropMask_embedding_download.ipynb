# %%
import ee
import time

ee.Initialize(project='kochias2',opt_url='https://earthengine-highvolume.googleapis.com')
out_folder = 'projects/kochias2/assets/CropMask_embedding'

# %%
# ------------------------------------------------------------------
# 0) PREP GRID, DATASET, MODEL, YEARS (same as before)
# ------------------------------------------------------------------
# grid = ee.FeatureCollection('projects/ee-thuan-ha/assets/grid_SK/grid_SK')
# grid = ee.FeatureCollection('projects/ee-thuan-ha/assets/grid_SK/grid_AB')
grid = ee.FeatureCollection('projects/ee-thuan-ha/assets/grid_SK/grid_MB')
n = grid.size()
grid_list = grid.toList(n)
ids = ee.List.sequence(1, n)

# %%
# shpID is your FeatureCollection with ID 1..n
shpID = ee.FeatureCollection(ids.zip(grid_list).map(lambda pair: ee.Feature(ee.List(pair).get(1)).set('ID', ee.List(pair).get(0))))
total_tiles = shpID.size().getInfo()
# print("Total tiles:", total_tiles)

# Server-side list of features (STAYS server-side)
shp_list = shpID.toList(total_tiles)

# On the Python side, we just track indices 0..total_tiles-1
indices = list(range(total_tiles))  # or subset if you want
print("Number of tiles to export:", len(indices))
# Out:
# Number of tiles to export: 239

# %%
def start_export_for_tile(idx):
    # idx is a Python int, used as index into server-side list
    fea  = ee.Feature(shp_list.get(idx))   # still server-side
    geom = fea.geometry()                  # server-side
    gid  = fea.get('ID').getInfo()         # one getInfo per task is OK

    per_year_coll = ee.ImageCollection(years.map(lambda y: classify_year(geom, y)))
    crop_sum = per_year_coll.sum().rename('crop_sum_2017_2024')

    desc     = f'CropSum2017_2024_SK_gridID_{gid}'
    asset_id = f'{out_folder}/{desc}'

    task = ee.batch.Export.image.toAsset(image=crop_sum, description=desc, assetId=asset_id, region=geom, scale=10, maxPixels=1e13)
    task.start()
    print(f"Started export for grid ID {gid}")
    return task

def start_export_for_tile(idx):
    fea  = ee.Feature(shp_list.get(idx))
    geom = fea.geometry()
    gid  = idx + 1  # matches ID sequence you set earlier

    per_year_coll = ee.ImageCollection(years.map(lambda y: classify_year(geom, y))    )
    crop_sum = per_year_coll.sum().rename('crop_sum_2017_2024')
    desc     = f'CropSum2017_2024_AB_gridID_{gid}'
    asset_id = f'{out_folder}/{desc}'
    
    # download task
    task = ee.batch.Export.image.toAsset(
        image=crop_sum, description=desc, assetId=asset_id,
        region=geom, scale=10, maxPixels=1e13    )
    task.start()
    print(f"Started export for grid ID {gid}")
    return task

def classify_year(geom, year):
    year = ee.Number(year)
    start = ee.Date.fromYMD(year, 1, 1)
    end_  = start.advance(1, 'year')
    img_year = (dataset.filterDate(start, end_).filterBounds(geom).mosaic().clip(geom))
    classified = (img_year.select(feature_bands).classify(rf_model).rename('crop'))  # 0/1 band

    return classified

# %%
# Input image frol Alpha Earth
batch_size   = 20
total_tiles  = len(indices)
years = ee.List.sequence(2017, 2024)
dataset = ee.ImageCollection('GOOGLE/SATELLITE_EMBEDDING/V1/ANNUAL')
feature_bands = dataset.first().bandNames()

rf_model = ee.Classifier.load('projects/just-amp-296821/assets/CropMask_embedding_saveModel/RF_CropMask_embedding_best_T200')


# Loop each grid tile and download
for start_idx in range(0, total_tiles, batch_size):
    batch_indices = indices[start_idx:start_idx + batch_size]
    print(f"\n=== Starting batch {start_idx}–{start_idx + len(batch_indices) - 1} ===")

    tasks = [start_export_for_tile(idx) for idx in batch_indices]
    # Poll until ALL tasks in this batch are finished
    while True:
        states = [t.status()['state'] for t in tasks]
        n_ready   = states.count('READY')
        n_running = states.count('RUNNING')
        n_done    = states.count('COMPLETED')
        n_failed  = states.count('FAILED')
        n_canc    = states.count('CANCELLED')

        print(f'Batch {start_idx}: READY={n_ready}, RUNNING={n_running}, '
              f'COMPLETED={n_done}, FAILED={n_failed}, CANCELLED={n_canc}')

        # Exit loop when no task is still pending
        if n_ready == 0 and n_running == 0:
            print(f'Batch {start_idx} finished.')
            break

        time.sleep(60)  # wait 60 seconds before checking again
# Out:
# === Starting batch 0–19 ===
# Started export for grid ID 1
# Started export for grid ID 2
# Started export for grid ID 3
# Started export for grid ID 4
# Started export for grid ID 5
# Started export for grid ID 6
# Started export for grid ID 7
# Started export for grid ID 8
# Started export for grid ID 9
# Started export for grid ID 10
# Started export for grid ID 11
# Started export for grid ID 12
# Started export for grid ID 13
# Started export for grid ID 14
# Started export for grid ID 15
# Started export for grid ID 16
# Started export for grid ID 17
# Started export for grid ID 18
# Started export for grid ID 19
# Started export for grid ID 20
# Batch 0: READY=18, RUNNING=2, COMPLETED=0, FAILED=0, CANCELLED=0
# Batch 0: READY=8, RUNNING=0, COMPLETED=0, FAILED=12, CANCELLED=0
# Batch 0: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 0 finished.
#
# === Starting batch 20–39 ===
# Started export for grid ID 21
# Started export for grid ID 22
# Started export for grid ID 23
# Started export for grid ID 24
# Started export for grid ID 25
# Started export for grid ID 26
# Started export for grid ID 27
# Started export for grid ID 28
# Started export for grid ID 29
# Started export for grid ID 30
# Started export for grid ID 31
# Started export for grid ID 32
# Started export for grid ID 33
# Started export for grid ID 34
# Started export for grid ID 35
# Started export for grid ID 36
# Started export for grid ID 37
# Started export for grid ID 38
# Started export for grid ID 39
# Started export for grid ID 40
# Batch 20: READY=20, RUNNING=0, COMPLETED=0, FAILED=0, CANCELLED=0
# Batch 20: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 20 finished.
#
# === Starting batch 40–59 ===
# Started export for grid ID 41
# Started export for grid ID 42
# Started export for grid ID 43
# Started export for grid ID 44
# Started export for grid ID 45
# Started export for grid ID 46
# Started export for grid ID 47
# Started export for grid ID 48
# Started export for grid ID 49
# Started export for grid ID 50
# Started export for grid ID 51
# Started export for grid ID 52
# Started export for grid ID 53
# Started export for grid ID 54
# Started export for grid ID 55
# Started export for grid ID 56
# Started export for grid ID 57
# Started export for grid ID 58
# Started export for grid ID 59
# Started export for grid ID 60
# Batch 40: READY=17, RUNNING=0, COMPLETED=0, FAILED=3, CANCELLED=0
# Batch 40: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 40 finished.
#
# === Starting batch 60–79 ===
# Started export for grid ID 61
# Started export for grid ID 62
# Started export for grid ID 63
# Started export for grid ID 64
# Started export for grid ID 65
# Started export for grid ID 66
# Started export for grid ID 67
# Started export for grid ID 68
# Started export for grid ID 69
# Started export for grid ID 70
# Started export for grid ID 71
# Started export for grid ID 72
# Started export for grid ID 73
# Started export for grid ID 74
# Started export for grid ID 75
# Started export for grid ID 76
# Started export for grid ID 77
# Started export for grid ID 78
# Started export for grid ID 79
# Started export for grid ID 80
# Batch 60: READY=20, RUNNING=0, COMPLETED=0, FAILED=0, CANCELLED=0
# Batch 60: READY=7, RUNNING=1, COMPLETED=0, FAILED=12, CANCELLED=0
# Batch 60: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 60 finished.
#
# === Starting batch 80–99 ===
# Started export for grid ID 81
# Started export for grid ID 82
# Started export for grid ID 83
# Started export for grid ID 84
# Started export for grid ID 85
# Started export for grid ID 86
# Started export for grid ID 87
# Started export for grid ID 88
# Started export for grid ID 89
# Started export for grid ID 90
# Started export for grid ID 91
# Started export for grid ID 92
# Started export for grid ID 93
# Started export for grid ID 94
# Started export for grid ID 95
# Started export for grid ID 96
# Started export for grid ID 97
# Started export for grid ID 98
# Started export for grid ID 99
# Started export for grid ID 100
# Batch 80: READY=20, RUNNING=0, COMPLETED=0, FAILED=0, CANCELLED=0
# Batch 80: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 80 finished.
#
# === Starting batch 100–119 ===
# Started export for grid ID 101
# Started export for grid ID 102
# Started export for grid ID 103
# Started export for grid ID 104
# Started export for grid ID 105
# Started export for grid ID 106
# Started export for grid ID 107
# Started export for grid ID 108
# Started export for grid ID 109
# Started export for grid ID 110
# Started export for grid ID 111
# Started export for grid ID 112
# Started export for grid ID 113
# Started export for grid ID 114
# Started export for grid ID 115
# Started export for grid ID 116
# Started export for grid ID 117
# Started export for grid ID 118
# Started export for grid ID 119
# Started export for grid ID 120
# Batch 100: READY=18, RUNNING=0, COMPLETED=0, FAILED=2, CANCELLED=0
# Batch 100: READY=1, RUNNING=1, COMPLETED=0, FAILED=18, CANCELLED=0
# Batch 100: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 100 finished.
#
# === Starting batch 120–139 ===
# Started export for grid ID 121
# Started export for grid ID 122
# Started export for grid ID 123
# Started export for grid ID 124
# Started export for grid ID 125
# Started export for grid ID 126
# Started export for grid ID 127
# Started export for grid ID 128
# Started export for grid ID 129
# Started export for grid ID 130
# Started export for grid ID 131
# Started export for grid ID 132
# Started export for grid ID 133
# Started export for grid ID 134
# Started export for grid ID 135
# Started export for grid ID 136
# Started export for grid ID 137
# Started export for grid ID 138
# Started export for grid ID 139
# Started export for grid ID 140
# Batch 120: READY=17, RUNNING=1, COMPLETED=0, FAILED=2, CANCELLED=0
# Batch 120: READY=5, RUNNING=0, COMPLETED=0, FAILED=15, CANCELLED=0
# Batch 120: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 120 finished.
#
# === Starting batch 140–159 ===
# Started export for grid ID 141
# Started export for grid ID 142
# Started export for grid ID 143
# Started export for grid ID 144
# Started export for grid ID 145
# Started export for grid ID 146
# Started export for grid ID 147
# Started export for grid ID 148
# Started export for grid ID 149
# Started export for grid ID 150
# Started export for grid ID 151
# Started export for grid ID 152
# Started export for grid ID 153
# Started export for grid ID 154
# Started export for grid ID 155
# Started export for grid ID 156
# Started export for grid ID 157
# Started export for grid ID 158
# Started export for grid ID 159
# Started export for grid ID 160
# Batch 140: READY=20, RUNNING=0, COMPLETED=0, FAILED=0, CANCELLED=0
# Batch 140: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 140 finished.
#
# === Starting batch 160–179 ===
# Started export for grid ID 161
# Started export for grid ID 162
# Started export for grid ID 163
# Started export for grid ID 164
# Started export for grid ID 165
# Started export for grid ID 166
# Started export for grid ID 167
# Started export for grid ID 168
# Started export for grid ID 169
# Started export for grid ID 170
# Started export for grid ID 171
# Started export for grid ID 172
# Started export for grid ID 173
# Started export for grid ID 174
# Started export for grid ID 175
# Started export for grid ID 176
# Started export for grid ID 177
# Started export for grid ID 178
# Started export for grid ID 179
# Started export for grid ID 180
# Batch 160: READY=17, RUNNING=0, COMPLETED=0, FAILED=3, CANCELLED=0
# Batch 160: READY=7, RUNNING=0, COMPLETED=0, FAILED=13, CANCELLED=0
# Batch 160: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 160 finished.
#
# === Starting batch 180–199 ===
# Started export for grid ID 181
# Started export for grid ID 182
# Started export for grid ID 183
# Started export for grid ID 184
# Started export for grid ID 185
# Started export for grid ID 186
# Started export for grid ID 187
# Started export for grid ID 188
# Started export for grid ID 189
# Started export for grid ID 190
# Started export for grid ID 191
# Started export for grid ID 192
# Started export for grid ID 193
# Started export for grid ID 194
# Started export for grid ID 195
# Started export for grid ID 196
# Started export for grid ID 197
# Started export for grid ID 198
# Started export for grid ID 199
# Started export for grid ID 200
# Batch 180: READY=20, RUNNING=0, COMPLETED=0, FAILED=0, CANCELLED=0
# Batch 180: READY=2, RUNNING=0, COMPLETED=0, FAILED=18, CANCELLED=0
# Batch 180: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 180 finished.
#
# === Starting batch 200–219 ===
# Started export for grid ID 201
# Started export for grid ID 202
# Started export for grid ID 203
# Started export for grid ID 204
# Started export for grid ID 205
# Started export for grid ID 206
# Started export for grid ID 207
# Started export for grid ID 208
# Started export for grid ID 209
# Started export for grid ID 210
# Started export for grid ID 211
# Started export for grid ID 212
# Started export for grid ID 213
# Started export for grid ID 214
# Started export for grid ID 215
# Started export for grid ID 216
# Started export for grid ID 217
# Started export for grid ID 218
# Started export for grid ID 219
# Started export for grid ID 220
# Batch 200: READY=20, RUNNING=0, COMPLETED=0, FAILED=0, CANCELLED=0
# Batch 200: READY=0, RUNNING=0, COMPLETED=0, FAILED=20, CANCELLED=0
# Batch 200 finished.
#
# === Starting batch 220–238 ===
# Started export for grid ID 221
# Started export for grid ID 222
# Started export for grid ID 223
# Started export for grid ID 224
# Started export for grid ID 225
# Started export for grid ID 226
# Started export for grid ID 227
# Started export for grid ID 228
# Started export for grid ID 229
# Started export for grid ID 230
# Started export for grid ID 231
# Started export for grid ID 232
# Started export for grid ID 233
# Started export for grid ID 234
# Started export for grid ID 235
# Started export for grid ID 236
# Started export for grid ID 237
# Started export for grid ID 238
# Started export for grid ID 239
# Batch 220: READY=19, RUNNING=0, COMPLETED=0, FAILED=0, CANCELLED=0
# Batch 220: READY=6, RUNNING=0, COMPLETED=0, FAILED=13, CANCELLED=0
# Batch 220: READY=0, RUNNING=0, COMPLETED=0, FAILED=19, CANCELLED=0
# Batch 220 finished.
